# %% [markdown]
# <a href="https://colab.research.google.com/github/riccardoisca-neuro/python-learning-roadmap/blob/main/code-foundry/simple_interest_yield_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ask the user to enter the savings

# %%
savings=input()
# Out:
# 150000

# %%
#Convert the user input into a float value and update the variable

# %%
savings= float(savings)

# %%
#Savings grow after 1 year at a 5% annual interest rate

# %%
balance=savings*1.05

# %%
#Convert the balance into a string and update the variable

# %%
balance= str(balance)

# %%
#Concatenate the 2 strings to produce a message

# %%
message="Amount in 1 year="+str(balance)

# %%
print(message)
# Out:
# Amount in 1 year=157500.0
